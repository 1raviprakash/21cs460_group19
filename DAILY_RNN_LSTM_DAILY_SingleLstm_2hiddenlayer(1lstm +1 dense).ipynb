# %%
# Stacked LSTM with 2 hidden layers (1dense layer and 1 LSTM layer)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.layers import ConvLSTM2D

# %%
# load the dataset
dataframe = read_csv('DATA_TEMP_DATE_JA_RNN.csv', usecols=[1])
plt.plot(dataframe)

# %%
#Convert pandas dataframe to numpy array
dataset = dataframe.values
dataset = dataset.astype('float32') #COnvert values to float

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) 
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)
    

seq_size = 10  # Number of time steps to look back 
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)



print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (11724, 10)
# Shape of test set: (2923, 10)

# %%
# Stacked LSTM with 2 hidden layers (1dense layer and 1 LSTM layer)
# reshape input to be [samples, time steps, features]

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(None, seq_size)))
model.add(LSTM(100, activation='relu'))
model.add(Dense(32))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()
print('Train...')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, None, 100)         44400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 32)                3232
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 128,065
# Trainable params: 128,065
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# 2021-11-14 22:36:14.279660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-14 22:36:14.417546: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2021-11-14 22:36:14.417760: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2021-11-14 22:36:14.417953: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2021-11-14 22:36:14.418137: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2021-11-14 22:36:14.430858: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-14 22:36:14.433344: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 367/367 - 2s - loss: 0.0147 - val_loss: 0.0023 - 2s/epoch - 6ms/step
# Epoch 2/100
# 367/367 - 1s - loss: 0.0017 - val_loss: 0.0017 - 684ms/epoch - 2ms/step
# Epoch 3/100
# 367/367 - 1s - loss: 0.0014 - val_loss: 0.0012 - 680ms/epoch - 2ms/step
# Epoch 4/100
# 367/367 - 1s - loss: 0.0012 - val_loss: 0.0015 - 696ms/epoch - 2ms/step
# Epoch 5/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0013 - 686ms/epoch - 2ms/step
# Epoch 6/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0010 - 676ms/epoch - 2ms/step
# Epoch 7/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0010 - 670ms/epoch - 2ms/step
# Epoch 8/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0012 - 680ms/epoch - 2ms/step
# Epoch 9/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0010 - 671ms/epoch - 2ms/step
# Epoch 10/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 674ms/epoch - 2ms/step
# Epoch 11/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0015 - 669ms/epoch - 2ms/step
# Epoch 12/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 669ms/epoch - 2ms/step
# Epoch 13/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 683ms/epoch - 2ms/step
# Epoch 14/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0010 - 671ms/epoch - 2ms/step
# Epoch 15/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 677ms/epoch - 2ms/step
# Epoch 16/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 9.9316e-04 - 685ms/epoch - 2ms/step
# Epoch 17/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 707ms/epoch - 2ms/step
# Epoch 18/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0011 - 673ms/epoch - 2ms/step
# Epoch 19/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 686ms/epoch - 2ms/step
# Epoch 20/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 685ms/epoch - 2ms/step
# Epoch 21/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 673ms/epoch - 2ms/step
# Epoch 22/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 680ms/epoch - 2ms/step
# Epoch 23/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 679ms/epoch - 2ms/step
# Epoch 24/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 701ms/epoch - 2ms/step
# Epoch 25/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 672ms/epoch - 2ms/step
# Epoch 26/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 671ms/epoch - 2ms/step
# Epoch 27/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 697ms/epoch - 2ms/step
# Epoch 28/100
# 367/367 - 1s - loss: 9.9904e-04 - val_loss: 0.0010 - 675ms/epoch - 2ms/step
# Epoch 29/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 676ms/epoch - 2ms/step
# Epoch 30/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0012 - 682ms/epoch - 2ms/step
# Epoch 31/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 676ms/epoch - 2ms/step
# Epoch 32/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 688ms/epoch - 2ms/step
# Epoch 33/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 670ms/epoch - 2ms/step
# Epoch 34/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 679ms/epoch - 2ms/step
# Epoch 35/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 731ms/epoch - 2ms/step
# Epoch 36/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 689ms/epoch - 2ms/step
# Epoch 37/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 802ms/epoch - 2ms/step
# Epoch 38/100
# 367/367 - 1s - loss: 9.9548e-04 - val_loss: 9.9821e-04 - 820ms/epoch - 2ms/step
# Epoch 39/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 729ms/epoch - 2ms/step
# Epoch 40/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 838ms/epoch - 2ms/step
# Epoch 41/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 700ms/epoch - 2ms/step
# Epoch 42/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0012 - 691ms/epoch - 2ms/step
# Epoch 43/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 725ms/epoch - 2ms/step
# Epoch 44/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 794ms/epoch - 2ms/step
# Epoch 45/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 724ms/epoch - 2ms/step
# Epoch 46/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0015 - 698ms/epoch - 2ms/step
# Epoch 47/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 825ms/epoch - 2ms/step
# Epoch 48/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 681ms/epoch - 2ms/step
# Epoch 49/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 9.9621e-04 - 855ms/epoch - 2ms/step
# Epoch 50/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 828ms/epoch - 2ms/step
# Epoch 51/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 854ms/epoch - 2ms/step
# Epoch 52/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 852ms/epoch - 2ms/step
# Epoch 53/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 672ms/epoch - 2ms/step
# Epoch 54/100
# 367/367 - 1s - loss: 9.9825e-04 - val_loss: 0.0010 - 682ms/epoch - 2ms/step
# Epoch 55/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 678ms/epoch - 2ms/step
# Epoch 56/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 9.9706e-04 - 673ms/epoch - 2ms/step
# Epoch 57/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 864ms/epoch - 2ms/step
# Epoch 58/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 757ms/epoch - 2ms/step
# Epoch 59/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 813ms/epoch - 2ms/step
# Epoch 60/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 9.9766e-04 - 736ms/epoch - 2ms/step
# Epoch 61/100
# 367/367 - 1s - loss: 9.9495e-04 - val_loss: 0.0011 - 763ms/epoch - 2ms/step
# Epoch 62/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 771ms/epoch - 2ms/step
# Epoch 63/100
# 367/367 - 1s - loss: 9.9265e-04 - val_loss: 0.0012 - 668ms/epoch - 2ms/step
# Epoch 64/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0013 - 693ms/epoch - 2ms/step
# Epoch 65/100
# 367/367 - 1s - loss: 9.9582e-04 - val_loss: 9.9867e-04 - 671ms/epoch - 2ms/step
# Epoch 66/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 678ms/epoch - 2ms/step
# Epoch 67/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 676ms/epoch - 2ms/step
# Epoch 68/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0019 - 697ms/epoch - 2ms/step
# Epoch 69/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0012 - 718ms/epoch - 2ms/step
# Epoch 70/100
# 367/367 - 1s - loss: 9.8307e-04 - val_loss: 0.0010 - 691ms/epoch - 2ms/step
# Epoch 71/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 767ms/epoch - 2ms/step
# Epoch 72/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 814ms/epoch - 2ms/step
# Epoch 73/100
# 367/367 - 1s - loss: 9.8867e-04 - val_loss: 0.0010 - 792ms/epoch - 2ms/step
# Epoch 74/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 715ms/epoch - 2ms/step
# Epoch 75/100
# 367/367 - 1s - loss: 9.8638e-04 - val_loss: 0.0013 - 708ms/epoch - 2ms/step
# Epoch 76/100
# 367/367 - 1s - loss: 9.9175e-04 - val_loss: 0.0012 - 742ms/epoch - 2ms/step
# Epoch 77/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 662ms/epoch - 2ms/step
# Epoch 78/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0015 - 811ms/epoch - 2ms/step
# Epoch 79/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 740ms/epoch - 2ms/step
# Epoch 80/100
# 367/367 - 1s - loss: 9.9706e-04 - val_loss: 0.0010 - 683ms/epoch - 2ms/step
# Epoch 81/100
# 367/367 - 1s - loss: 9.9999e-04 - val_loss: 0.0014 - 844ms/epoch - 2ms/step
# Epoch 82/100
# 367/367 - 1s - loss: 9.9965e-04 - val_loss: 0.0010 - 780ms/epoch - 2ms/step
# Epoch 83/100
# 367/367 - 1s - loss: 9.8488e-04 - val_loss: 9.9801e-04 - 781ms/epoch - 2ms/step
# Epoch 84/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 747ms/epoch - 2ms/step
# Epoch 85/100
# 367/367 - 1s - loss: 9.7408e-04 - val_loss: 0.0011 - 790ms/epoch - 2ms/step
# Epoch 86/100
# 367/367 - 1s - loss: 9.8400e-04 - val_loss: 0.0010 - 748ms/epoch - 2ms/step
# Epoch 87/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 723ms/epoch - 2ms/step
# Epoch 88/100
# 367/367 - 1s - loss: 9.8780e-04 - val_loss: 0.0011 - 775ms/epoch - 2ms/step
# Epoch 89/100
# 367/367 - 1s - loss: 9.9454e-04 - val_loss: 0.0011 - 840ms/epoch - 2ms/step
# Epoch 90/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 746ms/epoch - 2ms/step
# Epoch 91/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 844ms/epoch - 2ms/step
# Epoch 92/100
# 367/367 - 1s - loss: 9.9459e-04 - val_loss: 0.0010 - 716ms/epoch - 2ms/step
# Epoch 93/100
# 367/367 - 1s - loss: 9.8347e-04 - val_loss: 0.0011 - 755ms/epoch - 2ms/step
# Epoch 94/100
# 367/367 - 1s - loss: 9.8489e-04 - val_loss: 0.0010 - 847ms/epoch - 2ms/step
# Epoch 95/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 855ms/epoch - 2ms/step
# Epoch 96/100
# 367/367 - 1s - loss: 9.7824e-04 - val_loss: 9.8755e-04 - 792ms/epoch - 2ms/step
# Epoch 97/100
# 367/367 - 1s - loss: 9.7109e-04 - val_loss: 0.0010 - 685ms/epoch - 2ms/step
# Epoch 98/100
# 367/367 - 1s - loss: 9.9277e-04 - val_loss: 9.9359e-04 - 788ms/epoch - 2ms/step
# Epoch 99/100
# 367/367 - 1s - loss: 9.8015e-04 - val_loss: 0.0010 - 770ms/epoch - 2ms/step
# Epoch 100/100
# 367/367 - 1s - loss: 9.9936e-04 - val_loss: 9.9194e-04 - 739ms/epoch - 2ms/step

# %%
# make predictions

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions back to prescaled values
#This is to compare with original input values
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 1.06 RMSE
# Test Score: 1.10 RMSE

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset. 
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
# Train Score: 1.06 RMSE
# Test Score: 1.10 RMSE
