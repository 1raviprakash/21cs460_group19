# %%
# Bi-directional LSTM

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.layers import ConvLSTM2D

# %%
# load the dataset
dataframe = read_csv('DATA_TEMP_DATE_JA_RNN.csv', usecols=[1])
plt.plot(dataframe)

# %%
#Convert pandas dataframe to numpy array
dataset = dataframe.values
dataset = dataset.astype('float32') #COnvert values to float

# %%
scaler = MinMaxScaler(feature_range=(0, 1)) 
dataset = scaler.fit_transform(dataset)

# %%
train_size = int(len(dataset) * 0.80)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)
    

seq_size = 10  # Number of time steps to look back 
#Larger sequences (look further back) may improve forecasting.

trainX, trainY = to_sequences(train, seq_size)
testX, testY = to_sequences(test, seq_size)



print("Shape of training set: {}".format(trainX.shape))
print("Shape of test set: {}".format(testX.shape))
# Out:
# Shape of training set: (11724, 10)
# Shape of test set: (2923, 10)

# %%
#Bidirectional LSTM
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

##For some sequence forecasting problems we may need LSTM to learn
## sequence in both forward and backward directions

from keras.layers import Bidirectional
model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(None, seq_size)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
print('Train...')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 100)              24400
#  l)
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 24,501
# Trainable params: 24,501
# Non-trainable params: 0
# _________________________________________________________________
# Train...
# 2021-11-14 22:41:57.301822: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-14 22:41:57.309101: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2021-11-14 22:41:57.309305: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2021-11-14 22:41:57.309487: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2021-11-14 22:41:57.309666: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2021-11-14 22:41:57.310076: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-14 22:41:57.312142: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),
          verbose=2, epochs=100)
# Out:
# Epoch 1/100
# 367/367 - 2s - loss: 0.0189 - val_loss: 0.0020 - 2s/epoch - 6ms/step
# Epoch 2/100
# 367/367 - 0s - loss: 0.0016 - val_loss: 0.0015 - 431ms/epoch - 1ms/step
# Epoch 3/100
# 367/367 - 1s - loss: 0.0013 - val_loss: 0.0013 - 523ms/epoch - 1ms/step
# Epoch 4/100
# 367/367 - 0s - loss: 0.0012 - val_loss: 0.0013 - 450ms/epoch - 1ms/step
# Epoch 5/100
# 367/367 - 0s - loss: 0.0011 - val_loss: 0.0012 - 491ms/epoch - 1ms/step
# Epoch 6/100
# 367/367 - 1s - loss: 0.0011 - val_loss: 0.0011 - 560ms/epoch - 2ms/step
# Epoch 7/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0011 - 451ms/epoch - 1ms/step
# Epoch 8/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0012 - 484ms/epoch - 1ms/step
# Epoch 9/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 501ms/epoch - 1ms/step
# Epoch 10/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 473ms/epoch - 1ms/step
# Epoch 11/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0012 - 486ms/epoch - 1ms/step
# Epoch 12/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 432ms/epoch - 1ms/step
# Epoch 13/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 429ms/epoch - 1ms/step
# Epoch 14/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 487ms/epoch - 1ms/step
# Epoch 15/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 468ms/epoch - 1ms/step
# Epoch 16/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0012 - 497ms/epoch - 1ms/step
# Epoch 17/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 512ms/epoch - 1ms/step
# Epoch 18/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0011 - 430ms/epoch - 1ms/step
# Epoch 19/100
# 367/367 - 1s - loss: 9.9018e-04 - val_loss: 9.9898e-04 - 583ms/epoch - 2ms/step
# Epoch 20/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 469ms/epoch - 1ms/step
# Epoch 21/100
# 367/367 - 0s - loss: 9.9300e-04 - val_loss: 0.0010 - 451ms/epoch - 1ms/step
# Epoch 22/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0010 - 444ms/epoch - 1ms/step
# Epoch 23/100
# 367/367 - 0s - loss: 9.9274e-04 - val_loss: 0.0010 - 461ms/epoch - 1ms/step
# Epoch 24/100
# 367/367 - 0s - loss: 9.8760e-04 - val_loss: 0.0010 - 423ms/epoch - 1ms/step
# Epoch 25/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0011 - 510ms/epoch - 1ms/step
# Epoch 26/100
# 367/367 - 0s - loss: 9.9612e-04 - val_loss: 0.0011 - 475ms/epoch - 1ms/step
# Epoch 27/100
# 367/367 - 0s - loss: 9.9010e-04 - val_loss: 0.0010 - 443ms/epoch - 1ms/step
# Epoch 28/100
# 367/367 - 0s - loss: 9.7860e-04 - val_loss: 9.8672e-04 - 427ms/epoch - 1ms/step
# Epoch 29/100
# 367/367 - 0s - loss: 9.9224e-04 - val_loss: 9.9950e-04 - 417ms/epoch - 1ms/step
# Epoch 30/100
# 367/367 - 0s - loss: 0.0010 - val_loss: 0.0011 - 425ms/epoch - 1ms/step
# Epoch 31/100
# 367/367 - 0s - loss: 9.8706e-04 - val_loss: 0.0010 - 418ms/epoch - 1ms/step
# Epoch 32/100
# 367/367 - 0s - loss: 9.7687e-04 - val_loss: 0.0011 - 444ms/epoch - 1ms/step
# Epoch 33/100
# 367/367 - 0s - loss: 9.8042e-04 - val_loss: 0.0010 - 414ms/epoch - 1ms/step
# Epoch 34/100
# 367/367 - 0s - loss: 9.8309e-04 - val_loss: 9.8186e-04 - 422ms/epoch - 1ms/step
# Epoch 35/100
# 367/367 - 0s - loss: 9.7636e-04 - val_loss: 0.0011 - 436ms/epoch - 1ms/step
# Epoch 36/100
# 367/367 - 0s - loss: 9.9019e-04 - val_loss: 0.0010 - 420ms/epoch - 1ms/step
# Epoch 37/100
# 367/367 - 0s - loss: 9.8284e-04 - val_loss: 9.8389e-04 - 415ms/epoch - 1ms/step
# Epoch 38/100
# 367/367 - 0s - loss: 9.7577e-04 - val_loss: 9.8087e-04 - 428ms/epoch - 1ms/step
# Epoch 39/100
# 367/367 - 1s - loss: 9.8949e-04 - val_loss: 0.0011 - 515ms/epoch - 1ms/step
# Epoch 40/100
# 367/367 - 1s - loss: 0.0010 - val_loss: 0.0010 - 543ms/epoch - 1ms/step
# Epoch 41/100
# 367/367 - 1s - loss: 9.8884e-04 - val_loss: 0.0010 - 523ms/epoch - 1ms/step
# Epoch 42/100
# 367/367 - 0s - loss: 9.7096e-04 - val_loss: 0.0011 - 483ms/epoch - 1ms/step
# Epoch 43/100
# 367/367 - 0s - loss: 9.9327e-04 - val_loss: 9.9865e-04 - 431ms/epoch - 1ms/step
# Epoch 44/100
# 367/367 - 0s - loss: 9.6546e-04 - val_loss: 9.7859e-04 - 416ms/epoch - 1ms/step
# Epoch 45/100
# 367/367 - 0s - loss: 9.7924e-04 - val_loss: 0.0010 - 442ms/epoch - 1ms/step
# Epoch 46/100
# 367/367 - 0s - loss: 9.6888e-04 - val_loss: 9.8753e-04 - 441ms/epoch - 1ms/step
# Epoch 47/100
# 367/367 - 0s - loss: 9.7622e-04 - val_loss: 0.0010 - 500ms/epoch - 1ms/step
# Epoch 48/100
# 367/367 - 0s - loss: 9.7361e-04 - val_loss: 9.8609e-04 - 473ms/epoch - 1ms/step
# Epoch 49/100
# 367/367 - 0s - loss: 9.8790e-04 - val_loss: 0.0011 - 452ms/epoch - 1ms/step
# Epoch 50/100
# 367/367 - 0s - loss: 9.7772e-04 - val_loss: 9.9103e-04 - 475ms/epoch - 1ms/step
# Epoch 51/100
# 367/367 - 0s - loss: 9.6905e-04 - val_loss: 9.8722e-04 - 444ms/epoch - 1ms/step
# Epoch 52/100
# 367/367 - 0s - loss: 9.8198e-04 - val_loss: 9.7926e-04 - 470ms/epoch - 1ms/step
# Epoch 53/100
# 367/367 - 0s - loss: 9.7840e-04 - val_loss: 0.0010 - 453ms/epoch - 1ms/step
# Epoch 54/100
# 367/367 - 0s - loss: 9.5926e-04 - val_loss: 9.8093e-04 - 431ms/epoch - 1ms/step
# Epoch 55/100
# 367/367 - 0s - loss: 9.8545e-04 - val_loss: 9.8157e-04 - 471ms/epoch - 1ms/step
# Epoch 56/100
# 367/367 - 0s - loss: 9.7355e-04 - val_loss: 0.0011 - 428ms/epoch - 1ms/step
# Epoch 57/100
# 367/367 - 0s - loss: 9.6809e-04 - val_loss: 9.8589e-04 - 428ms/epoch - 1ms/step
# Epoch 58/100
# 367/367 - 0s - loss: 9.6933e-04 - val_loss: 9.7931e-04 - 434ms/epoch - 1ms/step
# Epoch 59/100
# 367/367 - 0s - loss: 9.6615e-04 - val_loss: 9.8721e-04 - 424ms/epoch - 1ms/step
# Epoch 60/100
# 367/367 - 1s - loss: 9.6579e-04 - val_loss: 0.0010 - 539ms/epoch - 1ms/step
# Epoch 61/100
# 367/367 - 1s - loss: 9.8126e-04 - val_loss: 9.9194e-04 - 501ms/epoch - 1ms/step
# Epoch 62/100
# 367/367 - 0s - loss: 9.7736e-04 - val_loss: 0.0010 - 425ms/epoch - 1ms/step
# Epoch 63/100
# 367/367 - 0s - loss: 9.7963e-04 - val_loss: 9.8298e-04 - 423ms/epoch - 1ms/step
# Epoch 64/100
# 367/367 - 0s - loss: 9.7301e-04 - val_loss: 0.0010 - 421ms/epoch - 1ms/step
# Epoch 65/100
# 367/367 - 0s - loss: 9.7453e-04 - val_loss: 0.0010 - 423ms/epoch - 1ms/step
# Epoch 66/100
# 367/367 - 0s - loss: 9.8310e-04 - val_loss: 9.8606e-04 - 437ms/epoch - 1ms/step
# Epoch 67/100
# 367/367 - 0s - loss: 9.8233e-04 - val_loss: 9.7825e-04 - 434ms/epoch - 1ms/step
# Epoch 68/100
# 367/367 - 0s - loss: 9.6886e-04 - val_loss: 9.8682e-04 - 431ms/epoch - 1ms/step
# Epoch 69/100
# 367/367 - 0s - loss: 9.5613e-04 - val_loss: 0.0011 - 496ms/epoch - 1ms/step
# Epoch 70/100
# 367/367 - 0s - loss: 9.6873e-04 - val_loss: 9.7772e-04 - 476ms/epoch - 1ms/step
# Epoch 71/100
# 367/367 - 0s - loss: 9.6786e-04 - val_loss: 0.0011 - 456ms/epoch - 1ms/step
# Epoch 72/100
# 367/367 - 0s - loss: 9.7291e-04 - val_loss: 0.0010 - 432ms/epoch - 1ms/step
# Epoch 73/100
# 367/367 - 0s - loss: 9.7043e-04 - val_loss: 0.0011 - 424ms/epoch - 1ms/step
# Epoch 74/100
# 367/367 - 0s - loss: 9.9022e-04 - val_loss: 9.7758e-04 - 435ms/epoch - 1ms/step
# Epoch 75/100
# 367/367 - 0s - loss: 9.6429e-04 - val_loss: 9.7950e-04 - 439ms/epoch - 1ms/step
# Epoch 76/100
# 367/367 - 0s - loss: 9.5803e-04 - val_loss: 9.7563e-04 - 434ms/epoch - 1ms/step
# Epoch 77/100
# 367/367 - 0s - loss: 9.6845e-04 - val_loss: 0.0010 - 443ms/epoch - 1ms/step
# Epoch 78/100
# 367/367 - 0s - loss: 9.7114e-04 - val_loss: 0.0010 - 431ms/epoch - 1ms/step
# Epoch 79/100
# 367/367 - 0s - loss: 9.7126e-04 - val_loss: 0.0010 - 440ms/epoch - 1ms/step
# Epoch 80/100
# 367/367 - 0s - loss: 9.6747e-04 - val_loss: 9.7874e-04 - 436ms/epoch - 1ms/step
# Epoch 81/100
# 367/367 - 0s - loss: 9.6976e-04 - val_loss: 9.8830e-04 - 430ms/epoch - 1ms/step
# Epoch 82/100
# 367/367 - 0s - loss: 9.6525e-04 - val_loss: 9.8339e-04 - 430ms/epoch - 1ms/step
# Epoch 83/100
# 367/367 - 0s - loss: 9.7544e-04 - val_loss: 0.0010 - 440ms/epoch - 1ms/step
# Epoch 84/100
# 367/367 - 0s - loss: 9.5767e-04 - val_loss: 0.0011 - 468ms/epoch - 1ms/step
# Epoch 85/100
# 367/367 - 0s - loss: 9.8275e-04 - val_loss: 9.9972e-04 - 433ms/epoch - 1ms/step
# Epoch 86/100
# 367/367 - 0s - loss: 9.7141e-04 - val_loss: 9.8920e-04 - 434ms/epoch - 1ms/step
# Epoch 87/100
# 367/367 - 0s - loss: 9.6499e-04 - val_loss: 9.8747e-04 - 443ms/epoch - 1ms/step
# Epoch 88/100
# 367/367 - 0s - loss: 9.6750e-04 - val_loss: 0.0011 - 441ms/epoch - 1ms/step
# Epoch 89/100
# 367/367 - 0s - loss: 9.6413e-04 - val_loss: 9.9812e-04 - 432ms/epoch - 1ms/step
# Epoch 90/100
# 367/367 - 0s - loss: 9.7066e-04 - val_loss: 9.8725e-04 - 437ms/epoch - 1ms/step
# Epoch 91/100
# 367/367 - 0s - loss: 9.6831e-04 - val_loss: 9.8664e-04 - 442ms/epoch - 1ms/step
# Epoch 92/100
# 367/367 - 0s - loss: 9.6909e-04 - val_loss: 0.0011 - 440ms/epoch - 1ms/step
# Epoch 93/100
# 367/367 - 0s - loss: 9.6612e-04 - val_loss: 9.8437e-04 - 428ms/epoch - 1ms/step
# Epoch 94/100
# 367/367 - 0s - loss: 9.5801e-04 - val_loss: 9.7739e-04 - 436ms/epoch - 1ms/step
# Epoch 95/100
# 367/367 - 0s - loss: 9.5822e-04 - val_loss: 9.8576e-04 - 449ms/epoch - 1ms/step
# Epoch 96/100
# 367/367 - 0s - loss: 9.5983e-04 - val_loss: 0.0010 - 439ms/epoch - 1ms/step
# Epoch 97/100
# 367/367 - 0s - loss: 9.6303e-04 - val_loss: 0.0010 - 443ms/epoch - 1ms/step
# Epoch 98/100
# 367/367 - 0s - loss: 9.6913e-04 - val_loss: 0.0010 - 437ms/epoch - 1ms/step
# Epoch 99/100
# 367/367 - 0s - loss: 9.6742e-04 - val_loss: 9.7766e-04 - 441ms/epoch - 1ms/step
# Epoch 100/100
# 367/367 - 0s - loss: 9.6994e-04 - val_loss: 0.0010 - 431ms/epoch - 1ms/step

# %%
# make predictions

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions back to prescaled values
#This is to compare with original input values
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))

testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 1.08 RMSE
# Test Score: 1.10 RMSE

# %%
# shift train predictions for plotting
#we must shift the predictions so that they align on the x-axis with the original dataset. 
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[seq_size:len(trainPredict)+seq_size, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(seq_size*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
# Train Score: 1.08 RMSE
# Test Score: 1.10 RMSE
